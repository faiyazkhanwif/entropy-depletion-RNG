# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Set up seaborn for better visuals
sns.set(style="whitegrid")

# Helper function to load simple list data from txt file
def load_simple_data(file_path):
    with open(file_path, 'r') as file:
        data = [float(line.strip()) for line in file]
    return data


# Test
#file_path = "data/01. Ubuntu 18.04.5 LTS/random_wait_log.txt"  # Replace with your actual file path
#data = load_simple_data(file_path)
#print(data)  # Prints the list of floating-point numbers


# Helper function to load system stats data from txt file
#def load_system_stats(file_path):
#    df = pd.read_csv(
#        file_path, 
#        skiprows=3, 
#        delim_whitespace=True, 
#        names=['time', 'CPU', '%user', '%nice', '%system', '%iowait', '%steal', '%idle']
#    )
#    # Parse time column
#    df['time'] = pd.to_datetime(df['time'], format='%I:%M:%S %p')
#    return df

# Read the system stats data
# Load system stats data with proper parsing
def load_system_stats(file_path):
    """
    This function loads system performance metrics from a log file while
    skipping unnecessary headers and parsing datetime values.
    """
    df = pd.read_csv(
        file_path,
        skiprows=4,  # Skip metadata and headers
        delim_whitespace=True,
        names=['time', 'CPU', '%user', '%nice', '%system', '%iowait', '%steal', '%idle'],
        on_bad_lines="skip"
    )

    # Parse the datetime properly from the string representation
    df['time'] = pd.to_datetime(df['time'], format='%I:%M:%S %p', errors='coerce')

    # Drop invalid datetime entries
    df.dropna(subset=['time'], inplace=True)

    return df



# Load data for - 01. Ubuntu 18.04.5 LTS
# Example file paths (replace with actual paths)
entropy_urandom = load_simple_data("data/01. Ubuntu 18.04.5 LTS/urandom_entropy_log.txt")
key_times_urandom = load_simple_data("data/01. Ubuntu 18.04.5 LTS/urandom_wait_log.txt")

entropy_random = load_simple_data("data/01. Ubuntu 18.04.5 LTS/random_entropy_log.txt")
key_times_random = load_simple_data("data/01. Ubuntu 18.04.5 LTS/random_wait_log.txt")

entropy_rsa = load_simple_data("data/01. Ubuntu 18.04.5 LTS/rsa_entropy_log.txt")
key_times_rsa = load_simple_data("data/01. Ubuntu 18.04.5 LTS/rsa_wait_log.txt")
system_stats = load_system_stats("data/01. Ubuntu 18.04.5 LTS/performance_metrics.txt")

print(f"Length of entropy_urandom: {len(entropy_urandom)}")
print(f"Length of entropy_random: {len(entropy_random)}")
print(f"Length of entropy_rsa: {len(entropy_rsa)}")

print(f"Length of key_times_urandom: {len(key_times_urandom)}")
print(f"Length of key_times_random: {len(key_times_random)}")
print(f"Length of key_times_rsa: {len(key_times_rsa)}")


# Convert data to DataFrames for analysis
entropy_df = pd.DataFrame({
    'urandom': entropy_urandom,
    'random': entropy_random,
    'rsa': entropy_rsa
})

time_df = pd.DataFrame({
    'urandom': key_times_urandom,
    'random': key_times_random,
    'rsa': key_times_rsa
})

print(time_df.head())


# --- Analysis and Visualization ---

# 1. Entropy Depletion Analysis
plt.figure(figsize=(12, 6))
plt.plot(entropy_df['urandom'], label="/dev/urandom", linestyle="-", marker="o")
plt.plot(entropy_df['random'], label="/dev/random", linestyle="--", marker="x")
plt.plot(entropy_df['rsa'], label="RSA", linestyle="-.", marker="s")
plt.title("Entropy Levels Over Time")
plt.xlabel("Time Steps")
plt.ylabel("Entropy Level")
plt.legend(loc='upper right')
plt.show()

# 1. Entropy Depletion Analysis (Zoomed to First 50 Keys)
plt.figure(figsize=(12, 6))
plt.plot(entropy_df['urandom'][:50], label="/dev/urandom", linestyle="-", marker="o")
plt.plot(entropy_df['random'][:50], label="/dev/random", linestyle="--", marker="x")
plt.plot(entropy_df['rsa'][:50], label="RSA", linestyle="-.", marker="s")
plt.title("Entropy Levels Over Time (First 50 Keys)")
plt.xlabel("Time Steps")
plt.ylabel("Entropy Level")
plt.legend(loc='upper right')
plt.show()

# 2. Key Generation Time Analysis - Fixing Scale Issues

# Histogram with Logarithmic x-axis
plt.figure(figsize=(12, 6))
for column in time_df.columns:
    sns.histplot(time_df[column], kde=True, bins=20, label=column, alpha=0.6)
plt.title("Distribution of Key Generation Times (Log Scale)")
plt.xlabel("Time (ms)")
plt.ylabel("Frequency")
plt.legend(title="Key Source")
plt.xscale('log')  # Apply log scale to x-axis
plt.show()



# 4. CPU Usage Analysis
#system_stats_long = system_stats.melt(
#    id_vars=['time'], 
#    value_vars=['%user', '%nice', '%system', '%iowait', '%steal', '%idle'],
#    var_name='Metric', 
#    value_name='Value'
#)
print(f"Rows successfully loaded: {system_stats.shape[0]}")
print(system_stats.head())  # View the first 5 rows



#plt.figure(figsize=(14, 8))
#sns.lineplot(data=system_stats_long, x='time', y='Value', hue='Metric')
#plt.title("CPU Usage Over Time")
#plt.ylabel("Percentage")
#plt.xticks(rotation=45)
#plt.legend(title="CPU Metrics")
#plt.show()
# Out:
# C:\Users\faiya\AppData\Local\Temp\ipykernel_16236\3379438355.py:42: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# C:\Users\faiya\AppData\Local\Temp\ipykernel_16236\3379438355.py:42: DtypeWarning: Columns (3,4,5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# Length of entropy_urandom: 2000
# Length of entropy_random: 2000
# Length of entropy_rsa: 2000
# Length of key_times_urandom: 1000
# Length of key_times_random: 1000
# Length of key_times_rsa: 1000
#    urandom     random   rsa
# 0      7.0  5886030.0   9.0
# 1      8.0  6906028.0  11.0
# 2      8.0  8278900.0  12.0
# 3      9.0  8540046.0  12.0
# 4      4.0  9251725.0  17.0
# Rows successfully loaded: 0
# Empty DataFrame
# Columns: [time, CPU, %user, %nice, %system, %iowait, %steal, %idle]
# Index: []

# %%
# Clean performance metrics csv
# Python script for processing the file, separating columns, and saving as a new CSV file.

import pandas as pd

# File path for the input and output files
input_file = '/mnt/data/performance_metrics.csv'
output_file = '/mnt/data/performance_metrics_cleaned.csv'

# Read the file, using whitespace as the delimiter to separate columns
data = pd.read_csv(input_file, delim_whitespace=True)

# Save the cleaned data to a new CSV file
data.to_csv(output_file, index=False)

# Display the first few rows of the cleaned data to confirm the structure
data.head(), output_file
# Out:
# Skipping line due to format issue: Linux 5.4.0-42-generic (avocados) 	2024-11-27 	_x86_64_	(6 CPU)
# Skipping line due to format issue: 04:47:09 PM     CPU     %user     %nice   %system   %iowait    %steal     %idle
# Skipping line due to format issue: 04:47:15 PM     CPU     %user     %nice   %system   %iowait    %steal     %idle
# Skipping line due to format issue: 04:47:21 PM     CPU     %user     %nice   %system   %iowait    %steal     %idle
# Skipping line due to format issue: 04:47:28 PM     CPU     %user     %nice   %system   %iowait    %steal     %idle
# Skipping line due to format issue: 04:47:34 PM     CPU     %user     %nice   %system   %iowait    %steal     %idle
# Skipping line due to format issue: 04:47:40 PM     CPU     %user     %nice   %system   %iowait    %steal     %idle
# Skipping line due to format issue: 04:47:46 PM     CPU     %user     %nice   %system   %iowait    %steal     %idle
# Skipping line due to format issue: 04:47:52 PM     CPU     %user     %nice   %system   %iowait    %steal     %idle
# Skipping line due to format issue: 04:47:58 PM     CPU     %user     %nice   %system   %iowait    %steal     %idle
# Skipping line due to format issue: 04:48:05 PM     CPU     %user     %nice   %system   %iowait    %steal     %idle
# Rows successfully loaded: 0
# Empty DataFrame
# Columns: [time, CPU, %user, %nice, %system, %iowait, %steal, %idle]
# Index: []
# No valid system stats data was parsed.
